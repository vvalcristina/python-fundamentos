# %% [markdown]
# ## Python - Fundamentos para a Análise de Dados
#
# ### Mini-projeto - Stream de Dados do Twitter
#
# Neste projeto vamos criar um stream de dados do [twitter](https://twitter.com/explore) com o Banco de Dados MongoDB e as libs Pandas(https://pandas.pydata.org/) e Scikit-Learn (https://scikit-learn.org/stable/).
#
# Este projeto consiste em aplicar técnincas de processamento de linguagem natural e métodos analíticos para extrair informações relevantes de dados de texto, o [Text Mining](https://www.linguamatics.com/what-text-mining-text-analytics-and-natural-language-processing).

# %% [markdown]
# **Twitter**
#
# O Twitter é uma fonte rica de informações sobre diversos assuntos. Podemos usar os dados para analisar tendências relacionados a uma palavra chave, analisar o sentimento relacionado a um determinado assunto e feedbacks de marcas.
#
# **Mongo DB**
#
# Banco de dados NoSQL que permite a integração entre certos tipos de aplicação, de forma fácil e rápido.
#
# Para obter esses dados será necessário a criação de uma API. Nesse caso vamos utilizar o [Twitter Stream API](https://developer.twitter.com/en/docs/tweets/filter-realtime/guides/basic-stream-parameters).
#
# **Obtendo as API's Keys:**
#
# * Crie uma conta no Twitter, caso ainda não possua.
# * Acesse as [apps](https://developer.twitter.com/en/apps) com seu usuário do Twitter.
# * Clique em 'Criar uma nova Aplicação'.
# * Preencha as informações e clique em "Criar T

# %% [markdown]
# **Instalando as libs necessárias**
#
# Para fazer essa análise vamos precisar utilizar o pacote Tweepy para fazer a comunicação com o Twitter.
#
# É necessário que o MongoDB esteja ativo, pois armazenaremos nossos dados nele.

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (3.8.0)
# Requirement already satisfied: six>=1.10.0 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/valeria.silva/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.9)

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# **Adicionando as chaves da API**
#
# Quando criamos uma conta como desenvolvedor no twitter recebemos algumas chaves.

# %%
#API key
consumer_key = "#################"

# %%
#API secret key
consumer_secret ="###############################"

# %%
#Access Token
access_token ="###############################################"

# %%
#Access Token Secret
token_secret="##################################################"

# %% [markdown]
# **Criando os objetos de autenticação**

# %%
#Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ### Preparando a conexão com o mongo

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
# Criando o banco de dados
db = client.twitterdb

# %%
#Criando a collection 
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Corona Virus', 'Brazil', 'Quarentena', 'Fique em casa']

# %% [markdown]
# ### Coletando os twitter

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Fri Jun 26 13:09:12 +0000 2020', 'id_str': '1276502774151176192', 'text': '@realDonaldTrump Really? Bullshit you LYING MORON!\n\nAmerica has 4% of the world’s population but 25% of the world’s… https://t.co/kduWFUMhfl', '_id': ObjectId('5ef5f37ceaa1177f658d90dc')}
# {'created_at': 'Fri Jun 26 13:09:12 +0000 2020', 'id_str': '1276502776923803649', 'text': 'RT @ateez_charts: #ATEEZ is trending  \n\n#11 Brazil\n#13 Mexico\n#15 France\n#22 Malaysia\n#32 United States\n#40 Singapore\n\n @ATEEZofficial http…', '_id': ObjectId('5ef5f37deaa1177f658d90dd')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502777368281088', 'text': 'RT @colelilivids: oxente o cole já foi em tantas festas durante essa quarentena, pq que cês tão brigando com ele dps de umas 6.000 festas q…', '_id': ObjectId('5ef5f37deaa1177f658d90de')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502777808785408', 'text': '@Lu_S_Maia A quarentena precisa acabar pelos brownies', '_id': ObjectId('5ef5f37deaa1177f658d90df')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502779213893632', 'text': '100 dias presa dentro de casa, respeitando a quarentena e vendo o resto do mundo vivendo normalmente 😃😃😃', '_id': ObjectId('5ef5f37deaa1177f658d90e0')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502779872174081', 'text': 'RT @raajjemv: avin corona virus halaakuvaakan engijje\nhttps://t.co/m9VHFDv1Ei', '_id': ObjectId('5ef5f37deaa1177f658d90e1')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502779910066176', 'text': 'RT @SarahTeodor0: Nunca engordei tanto igual eu engordei nessa quarentena, pqp', '_id': ObjectId('5ef5f37deaa1177f658d90e2')}
# {'created_at': 'Fri Jun 26 13:09:13 +0000 2020', 'id_str': '1276502781180829697', 'text': 'In case anyone still wants to oppose it without reading the article, it states the university is doing trials in Lo… https://t.co/uzmiVh2a2X', '_id': ObjectId('5ef5f37eeaa1177f658d90e3')}
# {'created_at': 'Fri Jun 26 13:09:14 +0000 2020', 'id_str': '1276502781541531652', 'text': 'RT @mr_mickey1: Now : corona virus cases are in hundreds \n\nAfter TS eamcet\n\nThen : cases are in thousands... \n\n@KTRTRS @TelanganaCMO @Sabit…', '_id': ObjectId('5ef5f37eeaa1177f658d90e4')}
# {'created_at': 'Fri Jun 26 13:09:14 +0000 2020', 'id_str': '1276502784750178309', 'text': "RT @joselitommutuc: NOIA's partnership with @OracleStartup adds 12 new servers to the NOIA Network. Locations include the U.S., Australia,…", '_id': ObjectId('5ef5f37eeaa1177f658d90e5')}
# {'created_at': 'Fri Jun 26 13:09:15 +0000 2020', 'id_str': '1276502786373345280', 'text': 'RT @kaitlancollins: "Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil." \n\nhttps://…', '_id': ObjectId('5ef5f37feaa1177f658d90e6')}
# {'created_at': 'Fri Jun 26 13:09:15 +0000 2020', 'id_str': '1276502788122595328', 'text': 'RT @dancarvalhoeu: não ter festa junina foi sem dúvida a maior maldade dessa quarentena', '_id': ObjectId('5ef5f37feaa1177f658d90e7')}
# {'created_at': 'Fri Jun 26 13:09:16 +0000 2020', 'id_str': '1276502791624642563', 'text': "j'ai vu que c'était en espagnol et j'ai vu l'emoji je me suis dit c'est sur une situation cocasse ou jsp mais en fa… https://t.co/JxiZzN5S8Z", '_id': ObjectId('5ef5f380eaa1177f658d90e8')}
# {'created_at': 'Fri Jun 26 13:09:16 +0000 2020', 'id_str': '1276502792669138945', 'text': 'RT @FIFAWorldCup: 📅 Six years ago today, Algeria reached the second round of the #WorldCup for the first time 🙌\n\n🇩🇿 We look at how Vahid Ha…', '_id': ObjectId('5ef5f380eaa1177f658d90e9')}
# {'created_at': 'Fri Jun 26 13:09:16 +0000 2020', 'id_str': '1276502792765497345', 'text': 'essa quarentena e fez ficar tão sensível que eu acordei e minha mãe não tinha comprado pão e meu deu vontade chorar', '_id': ObjectId('5ef5f380eaa1177f658d90ea')}
# {'created_at': 'Fri Jun 26 13:09:16 +0000 2020', 'id_str': '1276502793327726593', 'text': 'Vou fazer review das quinquilharias que comprei na quarentena\n\nSe eu virar um icone blogueira eu vou fingir que não… https://t.co/ryjj7TjKTR', '_id': ObjectId('5ef5f380eaa1177f658d90eb')}
# {'created_at': 'Fri Jun 26 13:09:17 +0000 2020', 'id_str': '1276502796536131584', 'text': '@gregiogabi que passe logo... estou com muita saudades de vcs aqui em casa!!! bjusss meu anjo.. fique bem!!', '_id': ObjectId('5ef5f381eaa1177f658d90ec')}
# {'created_at': 'Fri Jun 26 13:09:18 +0000 2020', 'id_str': '1276502799703031810', 'text': 'RT @kaitlancollins: "Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil." \n\nhttps://…', '_id': ObjectId('5ef5f382eaa1177f658d90ed')}
# {'created_at': 'Fri Jun 26 13:09:19 +0000 2020', 'id_str': '1276502804991860736', 'text': 'RT @lilitothenini_: queens breaking records\n\n#HowYouLikeThat\n#BLACKPINK #JENNIE #LISA #JISOO #ROSÉ\n@ygofficialblink', '_id': ObjectId('5ef5f383eaa1177f658d90ee')}
# {'created_at': 'Fri Jun 26 13:09:19 +0000 2020', 'id_str': '1276502805814169602', 'text': 'RT @brvnks: quarentena dia 999762837373 https://t.co/Rc0HoTpSLq', '_id': ObjectId('5ef5f383eaa1177f658d90ef')}
# {'created_at': 'Fri Jun 26 13:09:19 +0000 2020', 'id_str': '1276502805918826501', 'text': 'RT @taybegins: Dia 1000 da quarentena, dia 2 de sono regulado', '_id': ObjectId('5ef5f383eaa1177f658d90f0')}
# {'created_at': 'Fri Jun 26 13:09:20 +0000 2020', 'id_str': '1276502807214866432', 'text': 'https://t.co/uUbYsNpbRu #Cycling #Singapore #Brazil #Mexico #Hungary #Poland #Australia #Auckland #Sweden #Japan… https://t.co/zorW2CRyuF', '_id': ObjectId('5ef5f384eaa1177f658d90f1')}
# {'created_at': 'Fri Jun 26 13:09:20 +0000 2020', 'id_str': '1276502808125005824', 'text': 'provavelmente minha corrente favorita da quarentena https://t.co/MwXMUpME1p', '_id': ObjectId('5ef5f384eaa1177f658d90f2')}
# {'created_at': 'Fri Jun 26 13:09:20 +0000 2020', 'id_str': '1276502808611749889', 'text': 'RT @magnustatu: Pessoal se perguntando se a gente vai poder dar rolê até o final do ano.. não entendo, já tá todo mundo ignorando a quarent…', '_id': ObjectId('5ef5f384eaa1177f658d90f3')}
# {'created_at': 'Fri Jun 26 13:09:20 +0000 2020', 'id_str': '1276502810029428736', 'text': 'Quem controla os memes, controla o universo #NinguemFicaParaTrás #conservadores #Brasil #Brazil #Brics… https://t.co/8ghG0z5jvy', '_id': ObjectId('5ef5f384eaa1177f658d90f4')}
# {'created_at': 'Fri Jun 26 13:09:20 +0000 2020', 'id_str': '1276502810289336320', 'text': 'RT @MrDanZak: “Maricopa County, which includes Phoenix, is recording as many as 2,000 cases a day, eclipsing the New York City boroughs eve…', '_id': ObjectId('5ef5f384eaa1177f658d90f5')}
# {'created_at': 'Fri Jun 26 13:09:21 +0000 2020', 'id_str': '1276502811434508288', 'text': 'RT @PSVDotadoRO: Ando em casa de pau duro na quarentena kkkkk tá foda\nSolta aquele RT pra fortalecer https://t.co/h2GSYqq6MB', '_id': ObjectId('5ef5f385eaa1177f658d90f6')}
# {'created_at': 'Fri Jun 26 13:09:21 +0000 2020', 'id_str': '1276502811656757249', 'text': 'RT @richardhine: "#Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil... No state ha…', '_id': ObjectId('5ef5f385eaa1177f658d90f7')}
# {'created_at': 'Fri Jun 26 13:09:21 +0000 2020', 'id_str': '1276502813959319553', 'text': 'RT @BeatricedeDaz1: Mi mamá acaba de perder la lucha contra el corona virus 😭 cuiden sus vidas nadie lo hará por ustedes, se enfermó sin ha…', '_id': ObjectId('5ef5f385eaa1177f658d90f8')}
# {'created_at': 'Fri Jun 26 13:09:22 +0000 2020', 'id_str': '1276502814953480193', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f386eaa1177f658d90f9')}
# {'created_at': 'Fri Jun 26 13:09:22 +0000 2020', 'id_str': '1276502815322574848', 'text': 'RT @ughbrazil: [FOTO] Spring Day finalmente floresceu 😍\n\n#StayGold #StayGoldMV \n\n@BTS_twt | UGH Brazil https://t.co/xFGhhI3nuY', '_id': ObjectId('5ef5f386eaa1177f658d90fa')}
# {'created_at': 'Fri Jun 26 13:09:22 +0000 2020', 'id_str': '1276502816324857857', 'text': 'RT @PrinceRa321: बिहार: तेज़ी से बढ़ रहे कोरोना के मामलों के बीच नीतीश सरकार की लचर तैयारी\n#नीतीश_कुमार_टेस्ट_कराओ\n#पहले_जान_फिर_मतदान\n\nhtt…', '_id': ObjectId('5ef5f386eaa1177f658d90fb')}
# {'created_at': 'Fri Jun 26 13:09:22 +0000 2020', 'id_str': '1276502817599979521', 'text': 'RT @SandroGMoura: Amei a capa nova de que kaori.bruna fez para Luzes do Amanhã e outros contos. \n#cyberpunk #scifi #ficçãocientífica #liter…', '_id': ObjectId('5ef5f386eaa1177f658d90fc')}
# {'created_at': 'Fri Jun 26 13:09:22 +0000 2020', 'id_str': '1276502818640273409', 'text': 'RT @BeatricedeDaz1: Mi mamá acaba de perder la lucha contra el corona virus 😭 cuiden sus vidas nadie lo hará por ustedes, se enfermó sin ha…', '_id': ObjectId('5ef5f386eaa1177f658d90fd')}
# {'created_at': 'Fri Jun 26 13:09:23 +0000 2020', 'id_str': '1276502822696058880', 'text': 'RT @mototanaka: @CaskDiogenes スペイン語の話になりますがcoronaは女性名詞、coronavirusだと男性名詞です(virusが男性名詞なのでそれに引っ張られる)。ツリー元のCovid19が女性名詞という話は仏語で「コロナウイルス起源の病気」の…', '_id': ObjectId('5ef5f387eaa1177f658d90fe')}
# {'created_at': 'Fri Jun 26 13:09:23 +0000 2020', 'id_str': '1276502822725357569', 'text': 'RT @MrDanZak: “Maricopa County, which includes Phoenix, is recording as many as 2,000 cases a day, eclipsing the New York City boroughs eve…', '_id': ObjectId('5ef5f387eaa1177f658d90ff')}
# {'created_at': 'Fri Jun 26 13:09:24 +0000 2020', 'id_str': '1276502824830955522', 'text': '#upmedicoslivesmatter\n#genuine_demands\n#Against_Mass_Gathering\n#NoExamincovid\n#योगीजी_मेडिकोज_की_सुनो \nActually the… https://t.co/ZqUh9lDdWp', '_id': ObjectId('5ef5f388eaa1177f658d9100')}
# {'created_at': 'Fri Jun 26 13:09:24 +0000 2020', 'id_str': '1276502826198413312', 'text': 'achei que era o zayn', '_id': ObjectId('5ef5f388eaa1177f658d9101')}
# {'created_at': 'Fri Jun 26 13:09:25 +0000 2020', 'id_str': '1276502828945678339', 'text': 'RT @ughbrazil: [VOTAÇÃO] Armys nascidas entre maio e agosto, usem seus corações diários até 10:45! #StayGoldMV\n\nTag: #AttackOnSOBA\n@BTS_twt…', '_id': ObjectId('5ef5f389eaa1177f658d9102')}
# {'created_at': 'Fri Jun 26 13:09:25 +0000 2020', 'id_str': '1276502829004230656', 'text': 'RT @jhowsiel: sextou amigo hj era dia de inventar desculpa p mia o role\n\nvarias oportunidades de ser feliz perdidas\n\ne quando acabar a quar…', '_id': ObjectId('5ef5f389eaa1177f658d9103')}
# {'created_at': 'Fri Jun 26 13:09:25 +0000 2020', 'id_str': '1276502829163786241', 'text': 'RT @_leedantas: Se você não sabe quem é Suellen,  Yasmin Barbosa, mae da Yasmin, irmão engenheiro e empresário, Junior, Rubens, tio diretor…', '_id': ObjectId('5ef5f389eaa1177f658d9104')}
# {'created_at': 'Fri Jun 26 13:09:25 +0000 2020', 'id_str': '1276502831126773760', 'text': 'RT @kaitlancollins: "Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil." \n\nhttps://…', '_id': ObjectId('5ef5f389eaa1177f658d9105')}
# {'created_at': 'Fri Jun 26 13:09:26 +0000 2020', 'id_str': '1276502831827243008', 'text': 'RT @browngothbitch: Haha clearly noone paid attention in a level English to the crucible bc if u did u would realise the corona virus news…', '_id': ObjectId('5ef5f38aeaa1177f658d9106')}
# {'created_at': 'Fri Jun 26 13:09:26 +0000 2020', 'id_str': '1276502832183681025', 'text': 'a gente NUNCA vai sair da quarentena', '_id': ObjectId('5ef5f38aeaa1177f658d9107')}
# {'created_at': 'Fri Jun 26 13:09:26 +0000 2020', 'id_str': '1276502832255062016', 'text': 'A real é que a gente entra na quarentena querendo perder 5Kg... e depois de muito esforço e dedicação, faltam só 10. 😅', '_id': ObjectId('5ef5f38aeaa1177f658d9108')}
# {'created_at': 'Fri Jun 26 13:09:26 +0000 2020', 'id_str': '1276502833982918659', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f38aeaa1177f658d9109')}
# {'created_at': 'Fri Jun 26 13:09:27 +0000 2020', 'id_str': '1276502836315131904', 'text': 'RT @safadosdesejo: A quarentena tá durando mais que meus relacionamentos', '_id': ObjectId('5ef5f38beaa1177f658d910a')}
# {'created_at': 'Fri Jun 26 13:09:27 +0000 2020', 'id_str': '1276502836822421504', 'text': 'RT @khushal9900: #Save_GTU_Students\nGtu to corona virus* https://t.co/csCc0pti8s', '_id': ObjectId('5ef5f38beaa1177f658d910b')}
# {'created_at': 'Fri Jun 26 13:09:27 +0000 2020', 'id_str': '1276502839502798848', 'text': 'RT @belaalmadinha: a quarentena ta me fazendo PEGAR RANÇo de TODO MUNDO\n\neu vou sair odiando cada pessoa q eu conheço por um motivo diferen…', '_id': ObjectId('5ef5f38beaa1177f658d910c')}
# {'created_at': 'Fri Jun 26 13:09:27 +0000 2020', 'id_str': '1276502839687131136', 'text': '@BoudoirPriveUK I keep going to funerals of loved ones, friends etc\nThis is precisely what THIS&amp;OTHER governments h… https://t.co/hCsh1sQKhV', '_id': ObjectId('5ef5f38ceaa1177f658d910d')}
# {'created_at': 'Fri Jun 26 13:09:28 +0000 2020', 'id_str': '1276502842543497217', 'text': 'chuvinha abençoada para uma sexta de quarentena, ohh glória', '_id': ObjectId('5ef5f38ceaa1177f658d910e')}
# {'created_at': 'Fri Jun 26 13:09:28 +0000 2020', 'id_str': '1276502842618949632', 'text': 'RT @PhilipRucker: “Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil.”\n\nHow Arizona…', '_id': ObjectId('5ef5f38ceaa1177f658d910f')}
# {'created_at': 'Fri Jun 26 13:09:29 +0000 2020', 'id_str': '1276502846649892865', 'text': 'Galera🤣🤣🤣 olha aqui gente😝😝 eu furo quarentena😌😘😘 isso mesmo eu sou um doente mental☺️🤪🤪 filhinho de papai sem sens… https://t.co/LYddMjRJqY', '_id': ObjectId('5ef5f38deaa1177f658d9110')}
# {'created_at': 'Fri Jun 26 13:09:29 +0000 2020', 'id_str': '1276502847111213057', 'text': 'RT @safadosdesejo: A quarentena tá durando mais que meus relacionamentos', '_id': ObjectId('5ef5f38deaa1177f658d9111')}
# {'created_at': 'Fri Jun 26 13:09:30 +0000 2020', 'id_str': '1276502848440659969', 'text': 'RT @newsplatter: 😥. Please pikir lagi kalau bikin acara gathering/meet-up. Is it really worth the risk. https://t.co/ulr6IKa93r', '_id': ObjectId('5ef5f38eeaa1177f658d9112')}
# {'created_at': 'Fri Jun 26 13:09:30 +0000 2020', 'id_str': '1276502849623597056', 'text': "RT @JeremyKonyndyk: You can't gaslight the virus. You can't wish it away. You can't ignore it. And if each state has to learn that individu…", '_id': ObjectId('5ef5f38eeaa1177f658d9113')}
# {'created_at': 'Fri Jun 26 13:09:30 +0000 2020', 'id_str': '1276502850353401858', 'text': '@laurenleo_ deu um tempo o krl, é pq é mt dificil conseguir o cha com o traficante na quarentena ne kkkkkkk', '_id': ObjectId('5ef5f38eeaa1177f658d9114')}
# {'created_at': 'Fri Jun 26 13:09:30 +0000 2020', 'id_str': '1276502851015962625', 'text': 'RT @MrDanZak: “Maricopa County, which includes Phoenix, is recording as many as 2,000 cases a day, eclipsing the New York City boroughs eve…', '_id': ObjectId('5ef5f38eeaa1177f658d9115')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502852832198656', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f38feaa1177f658d9116')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502853494980608', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f38feaa1177f658d9117')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502853603987457', 'text': 'RT @th3j35t3r: Today Brazil\'s congress will vote on this law: "Registering accounts on social networks and interpersonal communication serv…', '_id': ObjectId('5ef5f38feaa1177f658d9118')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502855160000512', 'text': 'RT @MsCCollins1: " illegal"\nHow sad to hear humans gathering together described as " illegal"\nI fear for the democracy and individual freed…', '_id': ObjectId('5ef5f38feaa1177f658d9119')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502855462146048', 'text': 'RT @DeepStateExpose: RETWEET! Bill &amp; Melinda Gates planned the effects of a flu-like outbreak/"Corona Virus" using 5G in Wuhan, China! #Sca…', '_id': ObjectId('5ef5f38feaa1177f658d911a')}
# {'created_at': 'Fri Jun 26 13:09:31 +0000 2020', 'id_str': '1276502856678297601', 'text': 'RT @chartsblackpink: ‘How You Like That’ #1’s on iTunes (so far):\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic\n#1 Ecuador…', '_id': ObjectId('5ef5f390eaa1177f658d911b')}
# {'created_at': 'Fri Jun 26 13:09:32 +0000 2020', 'id_str': '1276502857164840960', 'text': 'RT @Adityag19624568: day by day lots of people are contact in corona virus. Train has been cancelled. University please cancelled all exami…', '_id': ObjectId('5ef5f390eaa1177f658d911c')}
# {'created_at': 'Fri Jun 26 13:09:32 +0000 2020', 'id_str': '1276502857718435848', 'text': 'RT @PCY61_sari: ایرانو میبینید😎🤩\u2066👐🏻\u2069\n\n#EXO \n@B_hundred_Hyun \n@weareoneEXO \n@layzhang', '_id': ObjectId('5ef5f390eaa1177f658d911d')}
# {'created_at': 'Fri Jun 26 13:09:32 +0000 2020', 'id_str': '1276502857970323458', 'text': 'RT @JuanDGut: The paper authored by Anna Binotto and Gustavo  Kastrup is close to the one that @Manuabarca01 and I will present tomorrow. T…', '_id': ObjectId('5ef5f390eaa1177f658d911e')}
# {'created_at': 'Fri Jun 26 13:09:32 +0000 2020', 'id_str': '1276502859358535682', 'text': '@DjNewAfrica IT HAS BEEN CURING FLUE EVER SINCE, BUT NOT DE WUHAN CORONA VIRUS DT CAME UP IN 2019...\nDE WUHAN ONE,… https://t.co/3KWzr0VwxV', '_id': ObjectId('5ef5f390eaa1177f658d911f')}
# {'created_at': 'Fri Jun 26 13:09:34 +0000 2020', 'id_str': '1276502866765721600', 'text': 'RT @BlitzSpitfire: Idéias da quarentena. Faça também e poste aqui. https://t.co/0DdPlHODmC', '_id': ObjectId('5ef5f392eaa1177f658d9120')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502870200913920', 'text': 'RT @maiyajanae_: Hmmm interesting places to start a vaccine trial', '_id': ObjectId('5ef5f393eaa1177f658d9121')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502870393860096', 'text': 'RT @VideoSertanejos: eu falo que to com sdd de sair de casa mas antes da quarentena eu recusava tds os convites pra sair', '_id': ObjectId('5ef5f393eaa1177f658d9122')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502872784547840', 'text': 'RT @llarafontes: O MOMENTO MAIS ESPERADO DA QUARENTENA! https://t.co/n4vdE9Jfx5', '_id': ObjectId('5ef5f393eaa1177f658d9123')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502872897646594', 'text': 'RT @chartsblackpink: ‘How You Like That’ #1’s on iTunes (so far):\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic\n#1 Ecuador…', '_id': ObjectId('5ef5f393eaa1177f658d9124')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502873166229505', 'text': 'tá, mas quem vai me levar na 1007 quando essa quarentena acabar?', '_id': ObjectId('5ef5f393eaa1177f658d9125')}
# {'created_at': 'Fri Jun 26 13:09:35 +0000 2020', 'id_str': '1276502873178767361', 'text': 'Felizmente nessa quarentena meu cabelo ta mais hidratado que nunca', '_id': ObjectId('5ef5f393eaa1177f658d9126')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502874206412800', 'text': 'RT @BeatricedeDaz1: Mi mamá acaba de perder la lucha contra el corona virus 😭 cuiden sus vidas nadie lo hará por ustedes, se enfermó sin ha…', '_id': ObjectId('5ef5f394eaa1177f658d9127')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502874428780544', 'text': 'RT @maddysknowles: I can’t wait for the day I can say “oh my god remember when corona virus was a thing”', '_id': ObjectId('5ef5f394eaa1177f658d9128')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502874336436225', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f394eaa1177f658d9129')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502874369986560', 'text': 'live da SHAKIRA......já estou me preparando ninguém vai me ouvir calar a boca, meu cf se preparem… https://t.co/ZpBnL48AHi', '_id': ObjectId('5ef5f394eaa1177f658d912a')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502875875745792', 'text': 'RT @thomassantanas: Eu odeio fofoca mais essa quarentena me obrigar a ser fofoqueiro', '_id': ObjectId('5ef5f394eaa1177f658d912b')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502876056178689', 'text': 'Desde um tempo na quarentena aqui em casa não guardamos mais a louça no lugar certo ela fica toda lá no escorredor… https://t.co/TjA4ogmYNL', '_id': ObjectId('5ef5f394eaa1177f658d912c')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502876681101312', 'text': 'The cure for corona? Chad', '_id': ObjectId('5ef5f394eaa1177f658d912d')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502877272326148', 'text': 'Bolsonaro steers Brazil erratically through coronavirus\xa0storm https://t.co/9Z6MTuD2qg', '_id': ObjectId('5ef5f394eaa1177f658d912e')}
# {'created_at': 'Fri Jun 26 13:09:36 +0000 2020', 'id_str': '1276502877326868480', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f394eaa1177f658d912f')}
# {'created_at': 'Fri Jun 26 13:09:37 +0000 2020', 'id_str': '1276502879491112963', 'text': 'Nessa quarentena eu engordei pacaraio', '_id': ObjectId('5ef5f395eaa1177f658d9130')}
# {'created_at': 'Fri Jun 26 13:09:37 +0000 2020', 'id_str': '1276502881546338305', 'text': 'i just might come to Brazil.\ntet tet tet.\nmet her late night, last night at a party in the Hills.\ntet tet tet.', '_id': ObjectId('5ef5f395eaa1177f658d9131')}
# {'created_at': 'Fri Jun 26 13:09:38 +0000 2020', 'id_str': '1276502883765309440', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f396eaa1177f658d9132')}
# {'created_at': 'Fri Jun 26 13:09:38 +0000 2020', 'id_str': '1276502885153607682', 'text': '@erica_graf 💹💰⚠️AVISO DE QUARENTENA⚠️💰💹\n\n. Não deixe de recarregar seu 📲 \n\n.1️⃣ Baixe o app RecargaPay \n\n.2️⃣ Faça… https://t.co/60VXx37SvH', '_id': ObjectId('5ef5f396eaa1177f658d9133')}
# {'created_at': 'Fri Jun 26 13:09:38 +0000 2020', 'id_str': '1276502885551882241', 'text': 'RT @Radardecoroas: Dois maduros turcos dando uma animada na quarentena. Delícia de foda desses dois. https://t.co/pxT8pIgqmx', '_id': ObjectId('5ef5f396eaa1177f658d9134')}
# {'created_at': 'Fri Jun 26 13:09:38 +0000 2020', 'id_str': '1276502886009188353', 'text': 'RT @PableOstos: Más pelaos que rodilla de chivo🤦\u200d♀️\nEs en Ciudad Guayana, Venezuela. \nNingún Brasil. https://t.co/RJ4gWf7zqO', '_id': ObjectId('5ef5f397eaa1177f658d9135')}
# {'created_at': 'Fri Jun 26 13:09:39 +0000 2020', 'id_str': '1276502886822731777', 'text': 'RT @hudtribbiani: eu em quarentena https://t.co/6FeS8USG11', '_id': ObjectId('5ef5f397eaa1177f658d9136')}
# {'created_at': 'Fri Jun 26 13:09:39 +0000 2020', 'id_str': '1276502887938641921', 'text': '@NacsUnderworld 💹💰⚠️AVISO DE QUARENTENA⚠️💰💹\n\n. Não deixe de recarregar seu 📲 \n\n.1️⃣ Baixe o app RecargaPay \n\n.2️⃣ F… https://t.co/0ArWvWlAK9', '_id': ObjectId('5ef5f397eaa1177f658d9137')}
# {'created_at': 'Fri Jun 26 13:09:39 +0000 2020', 'id_str': '1276502888580132872', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f397eaa1177f658d9138')}
# {'created_at': 'Fri Jun 26 13:09:39 +0000 2020', 'id_str': '1276502889561837574', 'text': '@raf1xzs só esperar a quarentena passar😈😈🔥', '_id': ObjectId('5ef5f397eaa1177f658d9139')}
# {'created_at': 'Fri Jun 26 13:09:39 +0000 2020', 'id_str': '1276502889741946881', 'text': 'RT @Ravisur34516840: कोरोना: बिहार के इन जिलों का हाल है खराब, संक्रमितों की संख्या 6736 हुई, अब तक 39 लोगों की मौत\n#नीतीश_कुमार_टेस्ट_कराओ…', '_id': ObjectId('5ef5f397eaa1177f658d913a')}
# {'created_at': 'Fri Jun 26 13:09:40 +0000 2020', 'id_str': '1276502890522087425', 'text': 'RT @NursingNow2020: Un placer reel estar con nuestros colegas del #NightingaleChallenge de #Mexico, #ElSalvador, #Brazil, #Chile y #Miami p…', '_id': ObjectId('5ef5f398eaa1177f658d913b')}
# {'created_at': 'Fri Jun 26 13:09:40 +0000 2020', 'id_str': '1276502890597748736', 'text': 'Senior Home in Brazil Creates ‘Hug Tunnel’ So Visitors Can Embrace Their Loved Ones https://t.co/Cz1KqYBR5b', '_id': ObjectId('5ef5f398eaa1177f658d913c')}
# {'created_at': 'Fri Jun 26 13:09:40 +0000 2020', 'id_str': '1276502892560609280', 'text': 'RT @tom_trotts: The @washingtonpost will excitedly analyze the effect that Fox News coverage of corona virus had on the public (which is at…', '_id': ObjectId('5ef5f398eaa1177f658d913d')}
# {'created_at': 'Fri Jun 26 13:09:40 +0000 2020', 'id_str': '1276502893034704896', 'text': 'RT @tressiemcphd: I cannot fathom how we won’t call this murder', '_id': ObjectId('5ef5f398eaa1177f658d913e')}
# {'created_at': 'Fri Jun 26 13:09:40 +0000 2020', 'id_str': '1276502893517029378', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f398eaa1177f658d913f')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502894825467912', 'text': '@quest_rik 💹💰⚠️AVISO DE QUARENTENA⚠️💰💹\n\n. Não deixe de recarregar seu 📲 \n\n.1️⃣ Baixe o app RecargaPay \n\n.2️⃣ Faça o… https://t.co/jUnZkxsJgC', '_id': ObjectId('5ef5f399eaa1177f658d9140')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502895001821189', 'text': 'RT @MattNavarra: .@Instagram is launching its TikTok-clone ‘Reels’ in Germany and France. \n\nPreviously only available in Brazil.   https://…', '_id': ObjectId('5ef5f399eaa1177f658d9141')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502895060414464', 'text': '@erica_graf 💹💰⚠️AVISO DE QUARENTENA⚠️💰💹\n\n. Não deixe de recarregar seu 📲 \n\n.1️⃣ Baixe o app RecargaPay \n\n.2️⃣ Faça… https://t.co/RLE4m6M5v6', '_id': ObjectId('5ef5f399eaa1177f658d9142')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502895257620481', 'text': 'Da série: Fique em casa\n#BlogdoMesquita #José #Mesquita https://t.co/7xMPaw35Lt', '_id': ObjectId('5ef5f399eaa1177f658d9143')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502896100532227', 'text': 'RT @ughbrazil: [FOTO] Spring Day finalmente floresceu 😍\n\n#StayGold #StayGoldMV \n\n@BTS_twt | UGH Brazil https://t.co/xFGhhI3nuY', '_id': ObjectId('5ef5f399eaa1177f658d9144')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502896146812928', 'text': 'RT @MrDanZak: “Maricopa County, which includes Phoenix, is recording as many as 2,000 cases a day, eclipsing the New York City boroughs eve…', '_id': ObjectId('5ef5f399eaa1177f658d9145')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502896926953472', 'text': 'Europeus sendo constante no seu mau caratismo há milênios', '_id': ObjectId('5ef5f399eaa1177f658d9146')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502897639989253', 'text': 'O erro do jovem em quarentena é ligar um funkao em uma sexta. Gatilha mais que tá pouco', '_id': ObjectId('5ef5f399eaa1177f658d9147')}
# {'created_at': 'Fri Jun 26 13:09:41 +0000 2020', 'id_str': '1276502898554404864', 'text': 'RT @arifa_1996: Thank you for teaching me lessons I failed to learn in 23 years', '_id': ObjectId('5ef5f39aeaa1177f658d9148')}
# {'created_at': 'Fri Jun 26 13:09:42 +0000 2020', 'id_str': '1276502899724554246', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f39aeaa1177f658d9149')}
# {'created_at': 'Fri Jun 26 13:09:43 +0000 2020', 'id_str': '1276502903172354048', 'text': 'RT @brunofribeiro: Todos não aguentamos mais a quarentena. Mas os números estão mostrando que ainda não daria pra ter reaberto SP. Da 1a. p…', '_id': ObjectId('5ef5f39beaa1177f658d914a')}
# {'created_at': 'Fri Jun 26 13:09:43 +0000 2020', 'id_str': '1276502903621062656', 'text': 'primeiro role de eletrônica pós quarentena a meta é ficar esquisita nesse nível', '_id': ObjectId('5ef5f39beaa1177f658d914b')}
# {'created_at': 'Fri Jun 26 13:09:43 +0000 2020', 'id_str': '1276502904707432450', 'text': '@victoroliveira chupa bom dia brazil', '_id': ObjectId('5ef5f39beaa1177f658d914c')}
# {'created_at': 'Fri Jun 26 13:09:44 +0000 2020', 'id_str': '1276502907534409728', 'text': 'RT @landpsychology: Blue Butterflies in the Amazon Rain Forest, Brazil https://t.co/D5FF9Okh7J', '_id': ObjectId('5ef5f39ceaa1177f658d914d')}
# {'created_at': 'Fri Jun 26 13:09:44 +0000 2020', 'id_str': '1276502907538604033', 'text': '@arafaelamenezes Eu acho que nessa quarentena eu tô conseguindo ficar muito mais na minha do que o normal. Acho que… https://t.co/s673M5sfUQ', '_id': ObjectId('5ef5f39ceaa1177f658d914e')}
# {'created_at': 'Fri Jun 26 13:09:44 +0000 2020', 'id_str': '1276502908872175617', 'text': 'RT @Umang38639170: Gtu vc want to take final year students exam but why he is not taking any responsibility of that none of the student get…', '_id': ObjectId('5ef5f39ceaa1177f658d914f')}
# {'created_at': 'Fri Jun 26 13:09:44 +0000 2020', 'id_str': '1276502909044371456', 'text': 'RT @nowlisboa: personagens de tvdu na quarentena; a thread. https://t.co/R2PyeEP0q8', '_id': ObjectId('5ef5f39ceaa1177f658d9150')}
# {'created_at': 'Fri Jun 26 13:09:44 +0000 2020', 'id_str': '1276502910235533313', 'text': 'quarentena acaba aí logo por favor eu tenho vários roles marcado pós quarentena, me ajuda aí', '_id': ObjectId('5ef5f39ceaa1177f658d9151')}
# {'created_at': 'Fri Jun 26 13:09:45 +0000 2020', 'id_str': '1276502914534502400', 'text': 'RT @RanaAyyub: An exploding Corona Virus crisis shows Narendra Modi is not up to the task of leading India. My latest for the Washington Po…', '_id': ObjectId('5ef5f39deaa1177f658d9152')}
# {'created_at': 'Fri Jun 26 13:09:45 +0000 2020', 'id_str': '1276502915218202625', 'text': 'conversando com pessoas próximas e lendo alguns tuítes, muita gente se sentindo palhaço por não furar a quarentena.… https://t.co/8cnC9lmhNV', '_id': ObjectId('5ef5f39eeaa1177f658d9153')}
# {'created_at': 'Fri Jun 26 13:09:46 +0000 2020', 'id_str': '1276502917797707776', 'text': 'बाळासाहेबांचा दणका...!\n\n✊✊', '_id': ObjectId('5ef5f39eeaa1177f658d9154')}
# {'created_at': 'Fri Jun 26 13:09:46 +0000 2020', 'id_str': '1276502917982359554', 'text': 'Omgggggggfff 😵😱🙏🏼👏🏼👏🏼🤩\n\nThank you for following me back my idol, I really love you so much, this is the happiest da… https://t.co/MqxmPGWNL1', '_id': ObjectId('5ef5f39eeaa1177f658d9155')}
# {'created_at': 'Fri Jun 26 13:09:47 +0000 2020', 'id_str': '1276502921530703874', 'text': '@1gabjr Só os filmes rendem um compromisso de 20 horas. Ideal em quarentena.', '_id': ObjectId('5ef5f39feaa1177f658d9156')}
# {'created_at': 'Fri Jun 26 13:09:47 +0000 2020', 'id_str': '1276502922038087680', 'text': 'RT @tetafunk: desde que a quarentena começou eu estou assim: maconha eu me entrego em suas mãos', '_id': ObjectId('5ef5f39feaa1177f658d9157')}
# {'created_at': 'Fri Jun 26 13:09:47 +0000 2020', 'id_str': '1276502923061542915', 'text': 'RT @PhilipRucker: “Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil.”\n\nHow Arizona…', '_id': ObjectId('5ef5f39feaa1177f658d9158')}
# {'created_at': 'Fri Jun 26 13:09:47 +0000 2020', 'id_str': '1276502923825098754', 'text': 'RT @zfabrogmailcom: Estamos todos encerrados em casa, apenas para postergar o pico que virá quando terminar a quarentena. Centenas de Empre…', '_id': ObjectId('5ef5f3a0eaa1177f658d9159')}
# {'created_at': 'Fri Jun 26 13:09:47 +0000 2020', 'id_str': '1276502923808108545', 'text': 'https://t.co/9QGZBqTseT\nHindus found another GOD. . And that is CORONA virus. .. Yes ... Corona Virus is their GOD', '_id': ObjectId('5ef5f3a0eaa1177f658d915a')}
# {'created_at': 'Fri Jun 26 13:09:48 +0000 2020', 'id_str': '1276502924143837185', 'text': '@nypost I have corona virus “symptoms” some mornings when I get up early after getting to bed late....', '_id': ObjectId('5ef5f3a0eaa1177f658d915b')}
# {'created_at': 'Fri Jun 26 13:09:48 +0000 2020', 'id_str': '1276502926421364736', 'text': 'RT @dr_mama_one: "He released the two seas, meeting [side by side] Between them is a barrier [so] neither of them transgresses. "(Q55:19-20…', '_id': ObjectId('5ef5f3a0eaa1177f658d915c')}
# {'created_at': 'Fri Jun 26 13:09:48 +0000 2020', 'id_str': '1276502927167893504', 'text': 'What in the ever loving fuck?', '_id': ObjectId('5ef5f3a0eaa1177f658d915d')}
# {'created_at': 'Fri Jun 26 13:09:49 +0000 2020', 'id_str': '1276502928463998976', 'text': 'RT @igorrealequatro: Não gosto de bancar o fiscal de quarentena de ninguém mas mentalmente não consigo perdoar quem é egoísta num momento e…', '_id': ObjectId('5ef5f3a1eaa1177f658d915e')}
# {'created_at': 'Fri Jun 26 13:09:49 +0000 2020', 'id_str': '1276502930946838528', 'text': '@Mr_LoLwa https://t.co/MPwGNxPMn7', '_id': ObjectId('5ef5f3a1eaa1177f658d915f')}
# {'created_at': 'Fri Jun 26 13:09:49 +0000 2020', 'id_str': '1276502931337076736', 'text': 'RT @PhilipRucker: “Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil.”\n\nHow Arizona…', '_id': ObjectId('5ef5f3a1eaa1177f658d9160')}
# {'created_at': 'Fri Jun 26 13:09:50 +0000 2020', 'id_str': '1276502933060771842', 'text': '@realDonaldTrump @POTUS \n\nI Think USA Govt should Keep Eye on All Chineez who Travel to USA in Jan, Feb,March 2020.… https://t.co/K29ck40c7S', '_id': ObjectId('5ef5f3a2eaa1177f658d9161')}
# {'created_at': 'Fri Jun 26 13:09:50 +0000 2020', 'id_str': '1276502933966905347', 'text': 'RT @DeepStateExpose: RETWEET! 5G is the real silent killer, not the "Corona Virus"!!!  https://t.co/ZRwKmA07zc', '_id': ObjectId('5ef5f3a2eaa1177f658d9162')}
# {'created_at': 'Fri Jun 26 13:09:50 +0000 2020', 'id_str': '1276502935577362434', 'text': "RT @beyoongc: Taeyeon's Happy, Blackpink's How You Like that, SHY in Yuri's Winning Recipe, Yeri's Room, Bae Joohyun dancing GIVE MY SOUL A…", '_id': ObjectId('5ef5f3a2eaa1177f658d9163')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502937020358656', 'text': 'RT @theoscarrgoesto: @UOLNoticias @gaiafayr Ainda furou a quarentena e incomodou o sossego alheio. Isso tudo porquê tava "escondido" hein?!', '_id': ObjectId('5ef5f3a3eaa1177f658d9164')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502937934508032', 'text': 'A quarentena tá durando mais que meus relacionamentos 🤦🏼\u200d♀️', '_id': ObjectId('5ef5f3a3eaa1177f658d9165')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502938370953217', 'text': 'RT @hyrbyair_marri: #China created a virus called #Corona in 2019.\n#Britain created a virus called #Pakistan in 1947.\nBoth are equally dang…', '_id': ObjectId('5ef5f3a3eaa1177f658d9166')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502939675299841', 'text': 'RT @kaitlancollins: "Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil." \n\nhttps://…', '_id': ObjectId('5ef5f3a3eaa1177f658d9167')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502938840514565', 'text': 'https://t.co/29Hxt8cMkU #Cycling #Singapore #Brazil #Mexico #Hungary #Poland #Australia #Auckland #Sweden #Japan… https://t.co/Sol8dt6rbk', '_id': ObjectId('5ef5f3a3eaa1177f658d9168')}
# {'created_at': 'Fri Jun 26 13:09:51 +0000 2020', 'id_str': '1276502940652646401', 'text': 'RT @dfaranha: In the same week, Brazil started voting a draconian fake news bill that introduces censorship, amplifies surveillance and wou…', '_id': ObjectId('5ef5f3a4eaa1177f658d9169')}
# {'created_at': 'Fri Jun 26 13:09:52 +0000 2020', 'id_str': '1276502942464516097', 'text': 'RT @DeepStateExpose: RETWEET! Bill &amp; Melinda Gates planned the effects of a flu-like outbreak/"Corona Virus" using 5G in Wuhan, China! #Sca…', '_id': ObjectId('5ef5f3a4eaa1177f658d916a')}
# {'created_at': 'Fri Jun 26 13:09:52 +0000 2020', 'id_str': '1276502943693496322', 'text': '#COVIDIOTS this one is on you', '_id': ObjectId('5ef5f3a4eaa1177f658d916b')}
# {'created_at': 'Fri Jun 26 13:09:52 +0000 2020', 'id_str': '1276502943806734337', 'text': 'RT @GlobalBlackPink: #BLACKPINK ‘How You Like That’ #1’s on iTunes: (16 #1’s)\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic…', '_id': ObjectId('5ef5f3a4eaa1177f658d916c')}
# {'created_at': 'Fri Jun 26 13:09:52 +0000 2020', 'id_str': '1276502944008024064', 'text': 'RT @apoyomutuo: La Pandemia del COVID-19 ha exacerbado otro virus: La violencia doméstica, principalmente contra la mujer. América Latina c…', '_id': ObjectId('5ef5f3a4eaa1177f658d916d')}
# {'created_at': 'Fri Jun 26 13:09:52 +0000 2020', 'id_str': '1276502944804818945', 'text': 'amei o conceito de furar a quarentena pra fumar narguile com os amigos com a máscara no queixo', '_id': ObjectId('5ef5f3a5eaa1177f658d916e')}
# {'created_at': 'Fri Jun 26 13:09:53 +0000 2020', 'id_str': '1276502945308303361', 'text': 'Ya ese viejito no hace sino tocer o talvez puede tener corona virus ojo con éso Video: Fuerte ataque de tos de Césa… https://t.co/d1CFjyYxGS', '_id': ObjectId('5ef5f3a5eaa1177f658d916f')}
# {'created_at': 'Fri Jun 26 13:09:53 +0000 2020', 'id_str': '1276502945463296002', 'text': '@realDonaldTrump Hey Trump we got to pick it up on testing Brazil has more cases than us which means they’ve done m… https://t.co/jluYrAa2jV', '_id': ObjectId('5ef5f3a5eaa1177f658d9170')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502949523488768', 'text': 'RT @TipicoGarota: Vocês também parecem estar vivendo o MESMO dia diversas vezes nessa quarentena?', '_id': ObjectId('5ef5f3a6eaa1177f658d9171')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502951905746945', 'text': "RT @divye_karnawat: Let's compare the dangers faced by medical students vs those of other colleges with respect to the novel Corona virus e…", '_id': ObjectId('5ef5f3a6eaa1177f658d9172')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502952107278338', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3a6eaa1177f658d9173')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502952543490048', 'text': 'RT @SEstrambotico: Chantaje mental, estafa PCR. Gripes y corona d siempre, mentira de los gobiernos covidianos. \nLas muertes: eutanasia en…', '_id': ObjectId('5ef5f3a6eaa1177f658d9174')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502952375660546', 'text': 'Eu chegando na uf dps da quarentena https://t.co/PvCc3129aV', '_id': ObjectId('5ef5f3a7eaa1177f658d9175')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502953260703744', 'text': 'RT @victoriaclobo: @RicaPerrone é o movimento “fique em casa pra não me ver fora de casa” rsrsrsrs', '_id': ObjectId('5ef5f3a7eaa1177f658d9176')}
# {'created_at': 'Fri Jun 26 13:09:54 +0000 2020', 'id_str': '1276502953247911936', 'text': 'a primeira cana dps da quarentena já me vejo assim', '_id': ObjectId('5ef5f3a7eaa1177f658d9177')}
# {'created_at': 'Fri Jun 26 13:09:55 +0000 2020', 'id_str': '1276502953986318337', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3a7eaa1177f658d9178')}
# {'created_at': 'Fri Jun 26 13:09:55 +0000 2020', 'id_str': '1276502955953393665', 'text': 'RT @wrmendonca80: Quarentena não é Férias Zezeu... Levanta e vai terminar os exercícios, ninguém mandou você ficar jogando até tarde vídeo…', '_id': ObjectId('5ef5f3a7eaa1177f658d9179')}
# {'created_at': 'Fri Jun 26 13:09:55 +0000 2020', 'id_str': '1276502956574212103', 'text': 'Marcus\' Playlist:" Where should i go?"\n\nme: BRAZIL ZIL ZIL :D', '_id': ObjectId('5ef5f3a7eaa1177f658d917a')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502958201614343', 'text': 'RT @vincentvanglock: Vocês mudaram muito do início da quarentena pra cá?? Pq eu pareço outra pessoa', '_id': ObjectId('5ef5f3a8eaa1177f658d917b')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502958381793280', 'text': 'RT @Irfanhziq_: Korang tahu tak sebenarnya virus tak dianggap sebagai benda hidup ! Haaa alang alang tengah musim corona ni jom kita kenal…', '_id': ObjectId('5ef5f3a8eaa1177f658d917c')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502959212261376', 'text': 'RT @provocamaremoto: Fifty-five thousand Brazilians die of a preventable disease.\n\nEuropeans: "maybe they\'re doing us a favour and showing…', '_id': ObjectId('5ef5f3a8eaa1177f658d917d')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502959824621573', 'text': 'RT @Social50forexo: Top countries tagging @weareoneEXO \n\nIndonesia\nPhilippines\nIran\nIndia\nUSA\nJapan\nS.Korea\nBangladesh\nPeru\nBrazil\nThailand…', '_id': ObjectId('5ef5f3a8eaa1177f658d917e')}
# {'created_at': 'Fri Jun 26 13:09:57 +0000 2020', 'id_str': '1276502961775091712', 'text': 'Acabou de publicar uma foto em Manaus, Brazil https://t.co/lznxQBDYFG', '_id': ObjectId('5ef5f3a9eaa1177f658d917f')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502959837208576', 'text': '@LuisaBathista Cara eu ODEIO. Eu vejo agora na quarentena o povo falando de ah, ficar em casa a mulher enchendo o s… https://t.co/uHvkudjX5T', '_id': ObjectId('5ef5f3a9eaa1177f658d9180')}
# {'created_at': 'Fri Jun 26 13:09:57 +0000 2020', 'id_str': '1276502964438515712', 'text': '@BelizeanBwoy2 I`m a super fan! whatsapp. 5521989721658. Rio de Janeiro. Brazil! I Iike you!', '_id': ObjectId('5ef5f3a9eaa1177f658d9181')}
# {'created_at': 'Fri Jun 26 13:09:57 +0000 2020', 'id_str': '1276502965507899395', 'text': 'choradinha do dia', '_id': ObjectId('5ef5f3aaeaa1177f658d9182')}
# {'created_at': 'Fri Jun 26 13:09:58 +0000 2020', 'id_str': '1276502966485127169', 'text': '@Anneelima_ cada um fala uma coisa ne mas fe em Deus q vai ser ead mesmo odeio mas melhor q morrer de corona virus', '_id': ObjectId('5ef5f3aaeaa1177f658d9183')}
# {'created_at': 'Fri Jun 26 13:09:56 +0000 2020', 'id_str': '1276502959837208576', 'text': '@LuisaBathista Cara eu ODEIO. Eu vejo agora na quarentena o povo falando de ah, ficar em casa a mulher enchendo o s… https://t.co/uHvkudjX5T', '_id': ObjectId('5ef5f3aaeaa1177f658d9184')}
# {'created_at': 'Fri Jun 26 13:09:58 +0000 2020', 'id_str': '1276502968343228417', 'text': 'Mais um chato no twitter.\nhttps://t.co/jTVpnaE20K', '_id': ObjectId('5ef5f3aaeaa1177f658d9185')}
# {'created_at': 'Fri Jun 26 13:09:58 +0000 2020', 'id_str': '1276502968955736066', 'text': 'RT @tiagojr21: Gatilho assim em plena quarentena é complicado', '_id': ObjectId('5ef5f3aaeaa1177f658d9186')}
# {'created_at': 'Fri Jun 26 13:09:59 +0000 2020', 'id_str': '1276502974098018305', 'text': '@arielsis A falsa sensação de segurança se da até quando disseram que a quarentena era a única saída. Nenhuma fórmula deu certo até agora.', '_id': ObjectId('5ef5f3aceaa1177f658d9187')}
# {'created_at': 'Fri Jun 26 13:10:00 +0000 2020', 'id_str': '1276502974622314496', 'text': 'ela pediu pra eu molhar as plantas dela enquanto ela tá fora eu n vo molhar nada vo deixar tudo morrer e quando aca… https://t.co/oZWQNHRcl8', '_id': ObjectId('5ef5f3aceaa1177f658d9188')}
# {'created_at': 'Fri Jun 26 13:10:00 +0000 2020', 'id_str': '1276502975385501696', 'text': 'Last week, President Maduro @maduro_en blamed the outbreak on countrymen flowing in from Colombia, which shares a p… https://t.co/Nka4hKlRRp', '_id': ObjectId('5ef5f3aceaa1177f658d9189')}
# {'created_at': 'Fri Jun 26 13:10:01 +0000 2020', 'id_str': '1276502980758515712', 'text': 'RT @malditaternura: Este periodista de @FinancialTimes nos cuenta lo que aquí nadie nos dice. De acuerdo a esta gráfica,\nLima tiene 289%  m…', '_id': ObjectId('5ef5f3adeaa1177f658d918a')}
# {'created_at': 'Fri Jun 26 13:10:00 +0000 2020', 'id_str': '1276502976174059521', 'text': 'RT @DILEEPK11820249: बिहार: तेज़ी से बढ़ रहे कोरोना के मामलों के बीच @NitishKumar सरकार की लचर तैयारी\n\n#नीतीश_कुमार_टेस्ट_कराओ\n#पहले_जान_फि…', '_id': ObjectId('5ef5f3adeaa1177f658d918b')}
# {'created_at': 'Fri Jun 26 13:10:00 +0000 2020', 'id_str': '1276502975041744896', 'text': 'RT @zfabrogmailcom: situação de outrora! Hoje, depois de 61 dias de quarentena obrigatória, e que parece que se prolonga novamente, o país…', '_id': ObjectId('5ef5f3adeaa1177f658d918c')}
# {'created_at': 'Fri Jun 26 13:10:01 +0000 2020', 'id_str': '1276502982612283394', 'text': "RT @IsimaOdeh: Pele is the World's Most Famous Footballer Ever. He had billions of fans. He was the World's Highest Paid Athlete. He made h…", '_id': ObjectId('5ef5f3aeeaa1177f658d918d')}
# {'created_at': 'Fri Jun 26 13:10:00 +0000 2020', 'id_str': '1276502975922548737', 'text': '@eualvesgilli Estamos no 101 dia de quarentena, aguente firme nada tá tão ruim que não possa piorar!', '_id': ObjectId('5ef5f3aeeaa1177f658d918e')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502983644073986', 'text': 'RT @kaitlancollins: "Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil." \n\nhttps://…', '_id': ObjectId('5ef5f3aeeaa1177f658d918f')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502983908290561', 'text': 'RT @maddysknowles: I can’t wait for the day I can say “oh my god remember when corona virus was a thing”', '_id': ObjectId('5ef5f3aeeaa1177f658d9190')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502984172724224', 'text': 'n bebo mais na quarentena', '_id': ObjectId('5ef5f3aeeaa1177f658d9191')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502985007222790', 'text': 'RT @jhowsiel: sextou amigo hj era dia de inventar desculpa p mia o role\n\nvarias oportunidades de ser feliz perdidas\n\ne quando acabar a quar…', '_id': ObjectId('5ef5f3aeeaa1177f658d9192')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502984973791233', 'text': 'RT @BorderAdvisor: The European Union is ready to reopen external borders on July 1, in efforts to revive tourism. However, Americans, Braz…', '_id': ObjectId('5ef5f3aeeaa1177f658d9193')}
# {'created_at': 'Fri Jun 26 13:10:02 +0000 2020', 'id_str': '1276502985087094785', 'text': 'RT @alepetry_: "Como você me descreveria" ... Jesus amado essas coisa da quarentena tão passando do limite cada dia uma diferente pra enche…', '_id': ObjectId('5ef5f3aeeaa1177f658d9194')}
# {'created_at': 'Fri Jun 26 13:10:03 +0000 2020', 'id_str': '1276502986857107456', 'text': 'RT @viniitj: @UOLNoticias @AndradeeRoberta #queiroz acaba de sair do isolamento social e já foi logo para o Lockdown,esse ai sabe se cuidar…', '_id': ObjectId('5ef5f3afeaa1177f658d9195')}
# {'created_at': 'Fri Jun 26 13:10:03 +0000 2020', 'id_str': '1276502987880361984', 'text': 'RT @maddysknowles: I can’t wait for the day I can say “oh my god remember when corona virus was a thing”', '_id': ObjectId('5ef5f3afeaa1177f658d9196')}
# {'created_at': 'Fri Jun 26 13:10:03 +0000 2020', 'id_str': '1276502990346731521', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3afeaa1177f658d9197')}
# ...
# {'created_at': 'Fri Jun 26 13:10:42 +0000 2020', 'id_str': '1276503154478153729', 'text': 'This was the first Carnegie Pops concert; guests could eat food and smoke while enjoying the music. UN members from… https://t.co/gVUJddW3BI', '_id': ObjectId('5ef5f3d7eaa1177f658d923a')}
# {'created_at': 'Fri Jun 26 13:10:43 +0000 2020', 'id_str': '1276503158680928257', 'text': 'mano que inferno \nalém da minha prima quebrar a porra da quarentena ela ainda vem pra MINHA casa e minha mãe fala q TUDO BEM \nVAI TOMA NO CU', '_id': ObjectId('5ef5f3d8eaa1177f658d923b')}
# {'created_at': 'Fri Jun 26 13:10:44 +0000 2020', 'id_str': '1276503160652210182', 'text': 'RT @hnrqmnzjr: Mesmo com as restrições da quarentena, cenas gravadas separadamente pelos artistas, MC Zaac, Anitta e Zaac vão entregar um c…', '_id': ObjectId('5ef5f3d8eaa1177f658d923c')}
# {'created_at': 'Fri Jun 26 13:10:44 +0000 2020', 'id_str': '1276503161205936128', 'text': '@StockCats I remember throwing coins and bills on the ground once they had no useful value while living in Brazil in 1994', '_id': ObjectId('5ef5f3d8eaa1177f658d923d')}
# {'created_at': 'Fri Jun 26 13:10:44 +0000 2020', 'id_str': '1276503161973293056', 'text': "RT @NeetuGarg6: We have a dynasty prince @RahulGandhi in India who don't know anything about Doklam, Rafale, NCC or Corona virus.\n\nBut he i…", '_id': ObjectId('5ef5f3d8eaa1177f658d923e')}
# {'created_at': 'Fri Jun 26 13:10:45 +0000 2020', 'id_str': '1276503163458256896', 'text': 'RT @TheOuterBanksBR: personagens de outer banks na quarentena; a thread. https://t.co/pr7I3EyVhT', '_id': ObjectId('5ef5f3d9eaa1177f658d923f')}
# {'created_at': 'Fri Jun 26 13:10:45 +0000 2020', 'id_str': '1276503164288561153', 'text': 'RT @CNTI_VE: ¡Feliz día!\nCumple con el distanciamiento físico y así entre todos/as le quitaremos la corona al virus\n\n#26Junio https://t.co/…', '_id': ObjectId('5ef5f3d9eaa1177f658d9240')}
# {'created_at': 'Fri Jun 26 13:10:45 +0000 2020', 'id_str': '1276503165748183042', 'text': 'RT @th3j35t3r: Today Brazil\'s congress will vote on this law: "Registering accounts on social networks and interpersonal communication serv…', '_id': ObjectId('5ef5f3d9eaa1177f658d9241')}
# {'created_at': 'Fri Jun 26 13:10:46 +0000 2020', 'id_str': '1276503169049063426', 'text': 'RT @komorebi3739: 皆様\nこんはんは。\n\n今夜の食後の珈琲\n\nYANAKA COFFEE\nBRAZIL\n"Floresta de Vicenzi"\nフローレスタ デ ヴィンセンチ\n\nデザートは\n直前にオーブントースターで\nチーズをとろりと溶かして頂く\n熱々の\n神…', '_id': ObjectId('5ef5f3daeaa1177f658d9242')}
# {'created_at': 'Fri Jun 26 13:10:46 +0000 2020', 'id_str': '1276503169736966154', 'text': 'RT @Lakshya03734173: #upmedicoslivesmatter\n#genuine_demands\n#Against_Mass_Gathering\n#NoExamincovid\n#योगीजी_मेडिकोज_की_सुनो \nActually the me…', '_id': ObjectId('5ef5f3daeaa1177f658d9243')}
# {'created_at': 'Fri Jun 26 13:10:46 +0000 2020', 'id_str': '1276503167795159040', 'text': '• June 26, 2015 •\n5 years ago today, @LanaParrilla, @sean_m_maguire, &amp; @bexmader were at the Ever After Convention… https://t.co/80WBPu9SUC', '_id': ObjectId('5ef5f3daeaa1177f658d9244')}
# {'created_at': 'Fri Jun 26 13:10:46 +0000 2020', 'id_str': '1276503170726821888', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3daeaa1177f658d9245')}
# {'created_at': 'Fri Jun 26 13:10:46 +0000 2020', 'id_str': '1276503171297349633', 'text': 'Após essa quarentena meu horário de somo tá lascado, dormindo 3h da manhã, acordando de 6hrs, dormindo de 12h e acordando de 17h, mt bom', '_id': ObjectId('5ef5f3dbeaa1177f658d9246')}
# {'created_at': 'Fri Jun 26 13:10:47 +0000 2020', 'id_str': '1276503171431632896', 'text': 'RT @GlobalBlackPink: #BLACKPINK ‘How You Like That’ #1’s on iTunes: (16 #1’s)\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic…', '_id': ObjectId('5ef5f3dbeaa1177f658d9247')}
# {'created_at': 'Fri Jun 26 13:10:47 +0000 2020', 'id_str': '1276503171930570752', 'text': 'RT @chartsblackpink: ‘How You Like That’ #1’s on iTunes (so far):\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic\n#1 Ecuador…', '_id': ObjectId('5ef5f3dbeaa1177f658d9248')}
# {'created_at': 'Fri Jun 26 13:10:47 +0000 2020', 'id_str': '1276503174891933696', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3dbeaa1177f658d9249')}
# {'created_at': 'Fri Jun 26 13:10:47 +0000 2020', 'id_str': '1276503175521095681', 'text': 'RT @d_gray_writer: I’m chuffed with how this, my first effort at editing and typesetting a whole book, has turned out. Lots of really enjoy…', '_id': ObjectId('5ef5f3dceaa1177f658d924a')}
# {'created_at': 'Fri Jun 26 13:10:48 +0000 2020', 'id_str': '1276503176418660355', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3dceaa1177f658d924b')}
# {'created_at': 'Fri Jun 26 13:10:48 +0000 2020', 'id_str': '1276503178599596032', 'text': 'Nossa isso aqui parece muitoo bom', '_id': ObjectId('5ef5f3dceaa1177f658d924c')}
# {'created_at': 'Fri Jun 26 13:10:49 +0000 2020', 'id_str': '1276503180386291713', 'text': '#BildungAberSicher (kfl)', '_id': ObjectId('5ef5f3ddeaa1177f658d924d')}
# {'created_at': 'Fri Jun 26 13:10:49 +0000 2020', 'id_str': '1276503180487073793', 'text': 'RT @richardhine: "#Arizona is facing more per capita cases than recorded by any country in Europe or even by hard-hit Brazil... No state ha…', '_id': ObjectId('5ef5f3ddeaa1177f658d924e')}
# {'created_at': 'Fri Jun 26 13:10:49 +0000 2020', 'id_str': '1276503183188283392', 'text': 'RT @thandostillau: yho ha.a corona virus mnqundu wakho san 😭😭', '_id': ObjectId('5ef5f3ddeaa1177f658d924f')}
# {'created_at': 'Fri Jun 26 13:10:50 +0000 2020', 'id_str': '1276503184442261504', 'text': 'RT @MrDanZak: “Maricopa County, which includes Phoenix, is recording as many as 2,000 cases a day, eclipsing the New York City boroughs eve…', '_id': ObjectId('5ef5f3deeaa1177f658d9250')}
# {'created_at': 'Fri Jun 26 13:10:50 +0000 2020', 'id_str': '1276503184572321792', 'text': 'RT @Jeff_Tymer_: LIVERPOOL FANS IN BRAZIL🇧🇷 https://t.co/dezSbJOCGC', '_id': ObjectId('5ef5f3deeaa1177f658d9251')}
# {'created_at': 'Fri Jun 26 13:10:50 +0000 2020', 'id_str': '1276503186350551041', 'text': '@cherryweed13 A fofoca é o que nos mantém vivos nessa quarentena', '_id': ObjectId('5ef5f3deeaa1177f658d9252')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503188510699520', 'text': 'RT @jhowsiel: sextou amigo hj era dia de inventar desculpa p mia o role\n\nvarias oportunidades de ser feliz perdidas\n\ne quando acabar a quar…', '_id': ObjectId('5ef5f3dfeaa1177f658d9253')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503188665851906', 'text': '@irlst i deaded at corona virus', '_id': ObjectId('5ef5f3dfeaa1177f658d9254')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503189467140096', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3dfeaa1177f658d9255')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503191094362119', 'text': 'RT @novinhxcarioca: Cadê a galera do Rio? Bora se conhecer pra marcar aquela social maneira depois da quarentena?! https://t.co/O7kfua3N8K', '_id': ObjectId('5ef5f3dfeaa1177f658d9256')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503191119519746', 'text': 'Erinaaaa 🇮🇩 🥰\n\nSemangat terus sayang2ku \nSemangat votenya, semangat tagnya, semangat streamingnya ❤️\n\nSehat dan bah… https://t.co/Wcwa9mog83', '_id': ObjectId('5ef5f3dfeaa1177f658d9257')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503191710871553', 'text': 'desde que descobri só consigo escutar a música pensando num boquete e passo mal de rir kkkkkkk', '_id': ObjectId('5ef5f3e0eaa1177f658d9258')}
# {'created_at': 'Fri Jun 26 13:10:51 +0000 2020', 'id_str': '1276503191710990336', 'text': 'RT @silvaa_emaa: tô assim nessa quarentena https://t.co/GVU0cDRYKy', '_id': ObjectId('5ef5f3e0eaa1177f658d9259')}
# {'created_at': 'Fri Jun 26 13:10:52 +0000 2020', 'id_str': '1276503192763879424', 'text': 'RT @LuittiCaminha: A cada dia de quarentena que passa eu fico mais Murilo Benício de cachecol desolado no show do coldplay das idéias https…', '_id': ObjectId('5ef5f3e0eaa1177f658d925a')}
# {'created_at': 'Fri Jun 26 13:10:52 +0000 2020', 'id_str': '1276503192902262784', 'text': 'i dont from brazil', '_id': ObjectId('5ef5f3e0eaa1177f658d925b')}
# {'created_at': 'Fri Jun 26 13:10:52 +0000 2020', 'id_str': '1276503193980153856', 'text': 'కేరళలో తగ్గుముఖం పడుతున్న కరోనా...!\n\n#corona-virus   #indiaherald  #indiaheraldgroup #Breaking-IndiaHerald #Telugu-… https://t.co/KoR7AYIozI', '_id': ObjectId('5ef5f3e0eaa1177f658d925c')}
# {'created_at': 'Fri Jun 26 13:10:52 +0000 2020', 'id_str': '1276503196278685696', 'text': 'RT @GlobalBlackPink: #BLACKPINK ‘How You Like That’ #1’s on iTunes: (16 #1’s)\n\n#1 Brazil\n#1 Cambodia\n#1 Chile\n#1 Colombia\n#1 Czech Republic…', '_id': ObjectId('5ef5f3e1eaa1177f658d925d')}
# {'created_at': 'Fri Jun 26 13:10:53 +0000 2020', 'id_str': '1276503196660142087', 'text': 'RT @GlobalBlackPink: #BLACKPINK\xa0 ‘How You Like That’ #1’s on iTunes: (42 #1’s)\n\n#1 United States\n#1 Belarus\n#1 Brazil\n#1 Brunei Darussalam…', '_id': ObjectId('5ef5f3e1eaa1177f658d925e')}
# {'created_at': 'Fri Jun 26 13:10:53 +0000 2020', 'id_str': '1276503197285146627', 'text': '#JogoWargoJogoNegoro\n#AyoJogoJeporo\n#BersamaKitaBisa\nBlue Light Patrol jajaran Polsek  Keling   guna mencegah penul… https://t.co/KS1qsBp1eD', '_id': ObjectId('5ef5f3e1eaa1177f658d925f')}
# {'created_at': 'Fri Jun 26 13:10:53 +0000 2020', 'id_str': '1276503199545868289', 'text': 'RT @YoloAkili: Fam. HIV is a virus. like the Flu. like Corona. It conveys NOTHING about the worthiness, practices or “morals” of the person…', '_id': ObjectId('5ef5f3e1eaa1177f658d9260')}
# {'created_at': 'Fri Jun 26 13:10:53 +0000 2020', 'id_str': '1276503200250638336', 'text': 'RT @skzwng: o minho é meu mood nessa quarentena https://t.co/oaNZ99F1tr', '_id': ObjectId('5ef5f3e1eaa1177f658d9261')}
# {'created_at': 'Fri Jun 26 13:10:54 +0000 2020', 'id_str': '1276503201152262145', 'text': 'RT @Pedriell: Dá pra você entender a pandemia do vírus socialista??? \nONDE TEM QUARENTENA, TEM CORRUPTO ROUBANDO!!! \nhttps://t.co/T7Uu9K5ETY', '_id': ObjectId('5ef5f3e2eaa1177f658d9262')}
# {'created_at': 'Fri Jun 26 13:10:54 +0000 2020', 'id_str': '1276503201462644740', 'text': 'RT @Y15299: #save_GTU_students\n@ugc please revise the guidelines as soon as possible otherwise more than 80k students of @GTUoffice are imp…', '_id': ObjectId('5ef5f3e2eaa1177f658d9263')}
# {'created_at': 'Fri Jun 26 13:10:54 +0000 2020', 'id_str': '1276503202880520193', 'text': 'RT @o_eco: Nota da Ascema conta que o servidor, que estava em operação no interior do Amazonas, teve sua transferência negada e está de qua…', '_id': ObjectId('5ef5f3e2eaa1177f658d9264')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# **Pressione STOP para finalizar a captura dos dados**
#
# ### Consultando os dados
#
# Agora vamos consultar nossos dados. É importante ressaltar que os dados são coletados no momento da análise.

# %% [markdown]
# mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5ef5f37ceaa1177f658d90dc'),
#  'created_at': 'Fri Jun 26 13:09:12 +0000 2020',
#  'id_str': '1276502774151176192',
#  'text': '@realDonaldTrump Really? Bullshit you LYING MORON!\n\nAmerica has 4% of the world’s population but 25% of the world’s… https://t.co/kduWFUMhfl'}

# %% [markdown]
# ### Análise dos Dados com Pandas e Sckit-Learn
#
# Vamos analisar os dados coletados

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                          created_at  \
# 0    Fri Jun 26 13:09:12 +0000 2020
# 1    Fri Jun 26 13:09:12 +0000 2020
# 2    Fri Jun 26 13:09:13 +0000 2020
# 3    Fri Jun 26 13:09:13 +0000 2020
# 4    Fri Jun 26 13:09:13 +0000 2020
# ..                              ...
# 388  Fri Jun 26 13:10:53 +0000 2020
# 389  Fri Jun 26 13:10:53 +0000 2020
# 390  Fri Jun 26 13:10:54 +0000 2020
# 391  Fri Jun 26 13:10:54 +0000 2020
# 392  Fri Jun 26 13:10:54 +0000 2020
#
#                                                   text
# 0    @realDonaldTrump Really? Bullshit you LYING MO...
# 1    RT @ateez_charts: #ATEEZ is trending  \n\n#11 ...
# 2    RT @colelilivids: oxente o cole já foi em tant...
# 3    @Lu_S_Maia A quarentena precisa acabar pelos b...
# 4    100 dias presa dentro de casa, respeitando a q...
# ..                                                 ...
# 388  RT @YoloAkili: Fam. HIV is a virus. like the F...
# 389  RT @skzwng: o minho é meu mood nessa quarenten...
# 390  RT @Pedriell: Dá pra você entender a pandemia ...
# 391  RT @Y15299: #save_GTU_students\n@ugc please re...
# 392  RT @o_eco: Nota da Ascema conta que o servidor...
#
# [393 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
import sklearn

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#           word  count
# 0           rt    260
# 1          the    190
# 2   quarentena    124
# 3           de    118
# 4        https    109
# 5           co    101
# 6        virus     85
# 7       corona     83
# 8         like     83
# 9           is     80
# 10      brazil     74
# 11          in     68
# 12          of     59
# 13         que     53
# 14          eu     49
# 15          or     44
# 16          da     40
# 17          it     39
# 18         flu     34
# 19       about     32
# 20   yoloakili     31
# 21      morals     31
# 22         hiv     31
# 23     nothing     31
# 24  worthiness     31
# 25     conveys     31
# 26      person     31
# 27   practices     31
# 28         fam     31
# 29          on     30
# 30         you     30
# 31          to     30
# 32          as     29
# 33          by     28
# 34        mais     26
# 35         não     26
# 36          na     26
# 37        that     26
# 38       cases     25
# 39         how     25
# 40         dia     23
# 41          se     22
# 42          do     22
# 43          em     22
# 44          me     20
# 45         and     20
# 46         pra     19
# 47         day     19
# 48          so     17
# 49     arizona     16

# %% [markdown]
# ## Referências##
#
# Doc Tweepy: https://www.tweepy.org/
