# %% [markdown]
# # Python Fundamentos para a Análise de Dados
#
# ### Cap 10 - TensorFlow
#
# Documentação [aqui](https://www.tensorflow.org/api_docs).

# %% [markdown]
# ### TensorFlow
#
# TensorFlow é uma das libs mais utilizadas para implementar Machine Learning ou algoritmos que envolvem grandes operações matemáticas. Foi desenvolvido pelo Google.
#
# Tensor matematicamente é um vetor de N-dimensões.

# %%
from IPython.display import Image
Image('tensor/tensor1.png')

# %% [markdown]
# ### TensorFlow x NumPy
#
# O NumPy tem suporte a matriz N-d, mas não oferece métodos para criar funções de tensor e automaticamente computar derivadas, além de não ter suporte a GPU, e esta é uma das principais razões para a existência do TensorFlow.

# %%
Image('tensor/tf_numpy.png')

# %% [markdown]
# ### Grapho Computacional
